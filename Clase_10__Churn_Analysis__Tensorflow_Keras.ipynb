# %% [markdown]
# # Curso Deep Learning
#
# <img src="https://yaelmanuel.com/wp-content/uploads/2021/12/platzi-banner-logo-matematicas.png" width="500px">
#
# ---

# %% [markdown]
# ## Creando nuestro propio Churn Analysis 🤓📊
#
# En este lab aprenderás:
#
# * [Tensorflow](https://www.tensorflow.org/)
# * [Keras](https://keras.io/)
# * Descargar un dataset, prepararlo, entrenarlo, realizar finetuning y guardarlo.

# %% [markdown]
# ### 1) Descarga del dataset 🤓
#
# Utilizaremos un conjunto de datos de un proveedor de Telecomunicaciones para su Programa de Retención.
# <br>Para más detalle acá se puede ver el dataset de Kaggle: [Telco Customer Churn](https://www.kaggle.com/datasets/blastchar/telco-customer-churn/data).

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s telco-customer-churn

# %%
# !kaggle datasets download -d blastchar/telco-customer-churn

# %%
# !unzip '/content/telco-customer-churn.zip'

# %% [markdown]
# ### 2) Preparación de la data 👌

# %% [markdown]
# #### 2.1) Instalamos las dependencias 🙌

# %%
# !pip install ydata-profiling

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# %% [markdown]
# #### 2.2) Explorar Dataset 🔍

# %%
# !ls

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv", sep=",")

# %% [markdown]
# **Tip:** Para visualizar todas las columnas del dataframe

# %%
df.head(3)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(3)

# %% [markdown]
# #### 2.3) EDA (Análisis Exploratorio de Datos)

# %% [markdown]
# Visualizamos qué tenemos en el dataframe

# %%
# Crear un resumen utilizando funciones nativas de pandas
def summarize_dataframe_with_pandas(df):
    summary = df.describe(include='all').T  # Descripción general
    summary['Type'] = df.dtypes  # Tipos de datos
    summary['Unique Values'] = df.nunique()  # Cantidad de valores únicos
    summary['Examples'] = df.apply(lambda col: col.dropna().unique()[:3])  # Ejemplos de valores

    # Reorganizar columnas para mejor visualización
    summary = summary[['Type', 'Unique Values', 'Examples']]
    return summary

# %%
summarize_dataframe_with_pandas(df)

# %% [markdown]
# Una visualización más detallada e interactiva

# %%
from ydata_profiling import ProfileReport

ProfileReport(df, minimal=True)

# %% [markdown]
# #### 2.4) Valores únicos

# %% [markdown]
# Eliminar columna con valores únicos

# %%
df = df.drop('customerID', axis=1)

# %% [markdown]
# Eliminar columna con que puede generar Bias o Sesgo

# %%
df = df.drop('gender', axis=1)

# %% [markdown]
# #### 2.5) Valores faltantes

# %%
# Evaluar cantidad de valores faltantes
df.isnull().sum()

# %% [markdown]
# #### 2.6) Columnas Categóricas

# %% [markdown]
# Reeplazo de valores binarios en columnas categóricas

# %%
# Evitar warning por uso de Replace
pd.set_option('future.no_silent_downcasting', True)

# %%
categorical_columns = list(df.select_dtypes(include='O').keys())

for i in categorical_columns:
    df[i] = df[i].replace('Yes', 1)
    df[i] = df[i].replace('No', 0)

# %% [markdown]
# Label Encoder

# %%
# Inicializar y aplicar LabelEncoder único
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))  # Codificar las columnas categóricas
    label_encoders[col] = le  # Guardar el codificador único para cada columna

# %%
# Guardar los label encoders
joblib.dump(label_encoders, 'label_encoders.pkl')

# %% [markdown]
# #### 2.7) Columnas Numéricas

# %% [markdown]
# Escalar la data

# %%
scale_cols = ['tenure','MonthlyCharges','TotalCharges']

scale = MinMaxScaler()
df[scale_cols] = scale.fit_transform(df[scale_cols])

# %%
# Guardar el escalado de datos
joblib.dump(scale, 'scaler.pkl')

# %% [markdown]
# ### 3) Entrenamiento 💪

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

print(xtrain.shape, ytrain.shape)

# %%
print(xtest.shape, ytest.shape)

# %% [markdown]
# ### 4) Red Neuronal 😨

# %%
# Obtener el número de columnas de entrenamiento
num_columns = 18

# %% [markdown]
# **Con Dropout**

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(num_columns,)),
    keras.layers.Dense(num_columns, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %% [markdown]
# **Con Regularización L1, L2 y L1+L2**

# %%
from tensorflow.keras import regularizers

# %%
"""
model = keras.Sequential([
    keras.layers.Input(shape=(num_columns,)),
    keras.layers.Dense(num_columns, activation='relu',
                 kernel_regularizer=regularizers.l1(0.01)),
    keras.layers.Dense(16, activation='relu',
                 kernel_regularizer=regularizers.l2(0.01)),
    keras.layers.Dense(10, activation='relu',
                 kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)),
    keras.layers.Dense(1, activation='sigmoid')
])
"""

# %% [markdown]
# **Explicación de porqué 16 neuronas:**
#
# - **Entrada:** El modelo utiliza 18 características.
# - **16 neuronas:** Elegido por ser cercano al número de características, siguiendo buenas prácticas iniciales.
# - **Balance:** Simple, funcional y eficiente para entrenamiento rápido.
# - **Base ajustable:** Diseñado para optimización futura con herramientas como KerasTuner.

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(
    optimizer = 'adamW',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
    )

# %%
# Agregamos el Early Stopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %% [markdown]
# **Probamos con 50 epochs**

# %%
# Implementamos un callback
history = model.fit(xtrain, ytrain, epochs=50, validation_data=(xtest, ytest), callbacks=[early_stop])
# Out:
# Epoch 1/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7291 - loss: 1.6412 - val_accuracy: 0.7317 - val_loss: 1.0584
# Epoch 2/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7234 - loss: 0.9446 - val_accuracy: 0.7317 - val_loss: 0.6827
# Epoch 3/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7420 - loss: 0.6272 - val_accuracy: 0.7317 - val_loss: 0.5725
# Epoch 4/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7537 - loss: 0.5441 - val_accuracy: 0.7722 - val_loss: 0.5493
# Epoch 5/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7551 - loss: 0.5323 - val_accuracy: 0.7686 - val_loss: 0.5391
# Epoch 6/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7663 - loss: 0.5258 - val_accuracy: 0.7310 - val_loss: 0.5325
# Epoch 7/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7529 - loss: 0.5153 - val_accuracy: 0.7757 - val_loss: 0.5265
# Epoch 8/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7637 - loss: 0.5167 - val_accuracy: 0.7949 - val_loss: 0.5213
# Epoch 9/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7880 - loss: 0.5033 - val_accuracy: 0.7906 - val_loss: 0.5168
# Epoch 10/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7840 - loss: 0.5046 - val_accuracy: 0.7956 - val_loss: 0.5136
# Epoch 11/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7761 - loss: 0.5078 - val_accuracy: 0.7871 - val_loss: 0.5125
# Epoch 12/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7817 - loss: 0.4947 - val_accuracy: 0.7885 - val_loss: 0.5097
# Epoch 13/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7798 - loss: 0.5132 - val_accuracy: 0.7970 - val_loss: 0.5068
# Epoch 14/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7764 - loss: 0.5063 - val_accuracy: 0.7970 - val_loss: 0.5059
# Epoch 15/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7870 - loss: 0.4909 - val_accuracy: 0.7977 - val_loss: 0.5034
# Epoch 16/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7840 - loss: 0.5013 - val_accuracy: 0.8041 - val_loss: 0.5022
# Epoch 17/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7904 - loss: 0.4881 - val_accuracy: 0.8006 - val_loss: 0.5005
# Epoch 18/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7995 - loss: 0.4779 - val_accuracy: 0.8020 - val_loss: 0.4986
# Epoch 19/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7954 - loss: 0.4803 - val_accuracy: 0.7921 - val_loss: 0.5009
# Epoch 20/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7797 - loss: 0.4890 - val_accuracy: 0.8027 - val_loss: 0.4961
# Epoch 21/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7985 - loss: 0.4824 - val_accuracy: 0.8020 - val_loss: 0.4949
# Epoch 22/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7903 - loss: 0.4862 - val_accuracy: 0.8013 - val_loss: 0.4930
# Epoch 23/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7919 - loss: 0.4850 - val_accuracy: 0.8055 - val_loss: 0.4925
# Epoch 24/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8026 - loss: 0.4849 - val_accuracy: 0.8027 - val_loss: 0.4905
# Epoch 25/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7964 - loss: 0.4815 - val_accuracy: 0.8041 - val_loss: 0.4897
# Epoch 26/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7980 - loss: 0.4893 - val_accuracy: 0.7991 - val_loss: 0.4911
# Epoch 27/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7923 - loss: 0.4802 - val_accuracy: 0.8006 - val_loss: 0.4888
# Epoch 28/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7943 - loss: 0.4835 - val_accuracy: 0.8027 - val_loss: 0.4867
# Epoch 29/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7965 - loss: 0.4782 - val_accuracy: 0.8062 - val_loss: 0.4856
# Epoch 30/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7927 - loss: 0.4776 - val_accuracy: 0.8084 - val_loss: 0.4845
# Epoch 31/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8041 - loss: 0.4754 - val_accuracy: 0.8027 - val_loss: 0.4856
# Epoch 32/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7877 - loss: 0.4787 - val_accuracy: 0.8084 - val_loss: 0.4840
# Epoch 33/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7897 - loss: 0.4831 - val_accuracy: 0.8041 - val_loss: 0.4864
# Epoch 34/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7900 - loss: 0.4744 - val_accuracy: 0.8062 - val_loss: 0.4815
# Epoch 35/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8037 - loss: 0.4648 - val_accuracy: 0.8062 - val_loss: 0.4815
# Epoch 36/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7907 - loss: 0.4836 - val_accuracy: 0.8041 - val_loss: 0.4807
# Epoch 37/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8066 - loss: 0.4663 - val_accuracy: 0.8077 - val_loss: 0.4797
# Epoch 38/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8003 - loss: 0.4691 - val_accuracy: 0.8084 - val_loss: 0.4826
# Epoch 39/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7944 - loss: 0.4817 - val_accuracy: 0.8084 - val_loss: 0.4794
# Epoch 40/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7935 - loss: 0.4850 - val_accuracy: 0.8084 - val_loss: 0.4780
# Epoch 41/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7967 - loss: 0.4649 - val_accuracy: 0.8055 - val_loss: 0.4778
# Epoch 42/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7952 - loss: 0.4723 - val_accuracy: 0.8112 - val_loss: 0.4774
# Epoch 43/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7949 - loss: 0.4704 - val_accuracy: 0.7991 - val_loss: 0.4778
# Epoch 44/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8011 - loss: 0.4719 - val_accuracy: 0.8077 - val_loss: 0.4765
# Epoch 45/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7898 - loss: 0.4745 - val_accuracy: 0.8098 - val_loss: 0.4761
# Epoch 46/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7903 - loss: 0.4777 - val_accuracy: 0.8105 - val_loss: 0.4764
# Epoch 47/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7970 - loss: 0.4675 - val_accuracy: 0.8077 - val_loss: 0.4745
# Epoch 48/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7934 - loss: 0.4752 - val_accuracy: 0.8077 - val_loss: 0.4740
# Epoch 49/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8024 - loss: 0.4707 - val_accuracy: 0.8070 - val_loss: 0.4735
# Epoch 50/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7876 - loss: 0.4790 - val_accuracy: 0.8105 - val_loss: 0.4768

# %% [markdown]
# ### 5) Métricas 📊

# %% [markdown]
# **Matriz de Confusión**

# %%
y_pred = (model.predict(xtest) > 0.5)  # Convertir las probabilidades a 0 o 1
cm = confusion_matrix(ytest, y_pred)

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.title("Matriz de Confusión")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# **Reporte de Métricas**

# %%
report = classification_report(ytest, y_pred, target_names=['No', 'Yes'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.92      0.87      1031
#          Yes       0.69      0.51      0.59       378
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.71      0.73      1409
# weighted avg       0.80      0.81      0.80      1409

# %% [markdown]
# **Gráfica de Accuracy**

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Accuracy Validación')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Gráfica de Loss**

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Entrenamiento')
plt.plot(history.history['val_loss'], label='Loss Validación')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# **Curva ROC**

# %%
# Obtener las predicciones de probabilidades
y_pred_train = (model.predict(xtrain) > 0.5)  # Convertir las probabilidades a 0 o 1

# Calcular las métricas de la curva ROC para entrenamiento
fpr_train, tpr_train, _ = roc_curve(ytrain, y_pred_train)
roc_auc_train = auc(fpr_train, tpr_train)

# Calcular las métricas de la curva ROC para validación
fpr_val, tpr_val, _ = roc_curve(ytest, y_pred)
roc_auc_val = auc(fpr_val, tpr_val)

# Graficar ambas curvas ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_train, tpr_train, color='blue', lw=2, label=f'Train ROC (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_val, tpr_val, color='green', lw=2, label=f'Validation ROC (AUC = {roc_auc_val:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--', lw=2, label='Random guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC)', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.grid(alpha=0.3)
plt.show()
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ### 6) Guardar el modelo 💾

# %% [markdown]
# ### 7) Hacer Predicciones en Producción 🤙

# %% [markdown]
# ### 8) Conclusiones
#
# - Aprender sobre los distintos objetos y métodos que nos ofrece Tensorflow + Keras.
#
# - Realizar el proceso completo de entrenamiento de un modelo con Tensorflow + Keras.
#
# - Aprender tips sobre implementación con el uso de la GPU.
#
# <br>
# <br>
# <br>

# %% [markdown]
# ---
#
# <br>
# <br>
#
#
# <img src="https://static.platzi.com/media/avatars/platziteam_8cfe6fc7-1246-4c9a-9f5d-d10d467443ee.png" width="100px">
#
# [Platzi](https://platzi.com/) 🚀
