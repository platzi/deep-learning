# %% [markdown]
# # Curso Deep Learning
#
# <img src="https://yaelmanuel.com/wp-content/uploads/2021/12/platzi-banner-logo-matematicas.png" width="500px">
#
# ---

# %% [markdown]
# ## Creando nuestro propio Churn Analysis 🤓📊
#
# En este lab aprenderás:
#
# * [Tensorflow](https://www.tensorflow.org/)
# * [Keras](https://keras.io/)
# * Descargar un dataset, prepararlo, entrenarlo, realizar finetuning y guardarlo.

# %% [markdown]
# ### 1) Descarga del dataset 🤓
#
# Utilizaremos un conjunto de datos de un proveedor de Telecomunicaciones para su Programa de Retención.
# <br>Para más detalle acá se puede ver el dataset de Kaggle: [Telco Customer Churn](https://www.kaggle.com/datasets/blastchar/telco-customer-churn/data).

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s telco-customer-churn

# %%
# !kaggle datasets download -d blastchar/telco-customer-churn

# %%
# !unzip '/content/telco-customer-churn.zip'

# %% [markdown]
# ### 2) Preparación de la data 👌

# %% [markdown]
# #### 2.1) Instalamos las dependencias 🙌

# %%
# !pip install ydata-profiling

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# %% [markdown]
# #### 2.2) Explorar Dataset 🔍

# %%
# !ls

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv", sep=",")

# %% [markdown]
# **Tip:** Para visualizar todas las columnas del dataframe

# %%
df.head(3)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(3)

# %% [markdown]
# #### 2.3) EDA (Análisis Exploratorio de Datos)

# %% [markdown]
# Visualizamos qué tenemos en el dataframe

# %%
# Crear un resumen utilizando funciones nativas de pandas
def summarize_dataframe_with_pandas(df):
    summary = df.describe(include='all').T  # Descripción general
    summary['Type'] = df.dtypes  # Tipos de datos
    summary['Unique Values'] = df.nunique()  # Cantidad de valores únicos
    summary['Examples'] = df.apply(lambda col: col.dropna().unique()[:3])  # Ejemplos de valores

    # Reorganizar columnas para mejor visualización
    summary = summary[['Type', 'Unique Values', 'Examples']]
    return summary

# %%
summarize_dataframe_with_pandas(df)

# %% [markdown]
# Una visualización más detallada e interactiva

# %%
from ydata_profiling import ProfileReport

ProfileReport(df, minimal=True)

# %% [markdown]
# #### 2.4) Valores únicos

# %% [markdown]
# Eliminar columna con valores únicos

# %%
df = df.drop('customerID', axis=1)

# %% [markdown]
# Eliminar columna con que puede generar Bias o Sesgo

# %%
df = df.drop('gender', axis=1)

# %% [markdown]
# #### 2.5) Valores faltantes

# %%
# Evaluar cantidad de valores faltantes
df.isnull().sum()

# %% [markdown]
# #### 2.6) Columnas Categóricas

# %% [markdown]
# Reeplazo de valores binarios en columnas categóricas

# %%
# Evitar warning por uso de Replace
pd.set_option('future.no_silent_downcasting', True)

# %%
categorical_columns = list(df.select_dtypes(include='O').keys())

for i in categorical_columns:
    df[i] = df[i].replace('Yes', 1)
    df[i] = df[i].replace('No', 0)

# %% [markdown]
# Label Encoder

# %%
# Inicializar y aplicar LabelEncoder único
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))  # Codificar las columnas categóricas
    label_encoders[col] = le  # Guardar el codificador único para cada columna

# %%
# Guardar los label encoders
joblib.dump(label_encoders, 'label_encoders.pkl')

# %% [markdown]
# #### 2.7) Columnas Numéricas

# %% [markdown]
# Escalar la data

# %%
scale_cols = ['tenure','MonthlyCharges','TotalCharges']

scale = MinMaxScaler()
df[scale_cols] = scale.fit_transform(df[scale_cols])

# %%
# Guardar el escalado de datos
joblib.dump(scale, 'scaler.pkl')

# %% [markdown]
# ### 3) Entrenamiento 💪

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

print(xtrain.shape, ytrain.shape)

# %%
print(xtest.shape, ytest.shape)

# %% [markdown]
# ### 4) Red Neuronal 😨

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.11/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (3.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.11/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras-tuner) (2024.12.14)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)

# %%
from keras_tuner import RandomSearch

# %%
# Obtener el número de columnas de entrenamiento
num_columns = 18

# %% [markdown]
# **Función para construir el modelo**

# %%
def build_model(hp):
    model = keras.Sequential([
        keras.layers.Input(shape=(num_columns,))
        ])

    # Primera capa con ajuste de unidades y función de activación
    model.add(keras.layers.Dense(units=hp.Int('units_layer1', min_value=10, max_value=16, step=2),
                    activation=hp.Choice('activation_layer1', values=['relu', 'tanh'])))

    # Dropout ajustable
    model.add(keras.layers.Dropout(rate=hp.Float('dropout_layer1', min_value=0.0, max_value=0.5, step=0.1)))

    # Segunda capa opcional
    if hp.Boolean('second_layer'):
        model.add(keras.layers.Dense(units=hp.Int('units_layer2', min_value=5, max_value=10, step=1),
                        activation=hp.Choice('activation_layer2', values=['relu', 'tanh'])))
        model.add(keras.layers.Dropout(rate=hp.Float('dropout_layer2', min_value=0.0, max_value=0.5, step=0.1)))

    # Capa de salida
    model.add(keras.layers.Dense(1, activation='sigmoid'))

    # Compilación
    model.compile(
        optimizer=hp.Choice('optimizer', values=['adam', 'adamW']),
        loss='binary_crossentropy',
        metrics=['accuracy'])

    return model

# %% [markdown]
# **Configurar KerasTuner**

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',  # Métrica a optimizar
    max_trials=10,             # Número de combinaciones a probar
    executions_per_trial=2,    # Número de ejecuciones por combinación
    directory='my_dir',        # Carpeta para guardar resultados
    project_name='churn_tuning'  # Nombre del proyecto
)

# %% [markdown]
# **Ejecutar la búsqueda**
#
# Vamos a probar con 20 epochs

# %%
tuner.search(xtrain, ytrain, epochs=20, validation_data=(xtest, ytest))
# Out:
# Trial 10 Complete [00h 00m 31s]
# val_accuracy: 0.8058907091617584
#
# Best val_accuracy So Far: 0.8083747327327728
# Total elapsed time: 00h 04m 55s

# %% [markdown]
# **Obtener el mejor modelo**

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Mejores hiperparámetros encontrados:")
print(f"- Unidades primera capa: {best_hps.get('units_layer1')}")
print(f"- Optimizer: {best_hps.get('optimizer')}")
print(f"- Dropout primera capa: {best_hps.get('dropout_layer1')}")
# Out:
# Mejores hiperparámetros encontrados:
# - Unidades primera capa: 12
# - Optimizer: adam
# - Dropout primera capa: 0.1

# %% [markdown]
# **Construir el mejor modelo**

# %%
best_model = tuner.hypermodel.build(best_hps)

# %%
keras.utils.plot_model(best_model, show_shapes=True)

# %% [markdown]
# **Entrenar el mejor modelo**
#
# Probamos con 50 epochs

# %%
# Agregamos el Early Stopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = best_model.fit(xtrain, ytrain, epochs=50, validation_data=(xtest, ytest), callbacks=[early_stop])
# Out:
# Epoch 1/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7196 - loss: 0.5667 - val_accuracy: 0.7828 - val_loss: 0.4616
# Epoch 2/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7721 - loss: 0.4659 - val_accuracy: 0.7956 - val_loss: 0.4390
# Epoch 3/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7764 - loss: 0.4537 - val_accuracy: 0.8006 - val_loss: 0.4324
# Epoch 4/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7771 - loss: 0.4525 - val_accuracy: 0.7999 - val_loss: 0.4293
# Epoch 5/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7953 - loss: 0.4267 - val_accuracy: 0.7977 - val_loss: 0.4277
# Epoch 6/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7830 - loss: 0.4364 - val_accuracy: 0.8020 - val_loss: 0.4263
# Epoch 7/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4261 - val_accuracy: 0.8027 - val_loss: 0.4254
# Epoch 8/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.4296 - val_accuracy: 0.8084 - val_loss: 0.4251
# Epoch 9/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.4332 - val_accuracy: 0.8034 - val_loss: 0.4230
# Epoch 10/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7890 - loss: 0.4228 - val_accuracy: 0.8070 - val_loss: 0.4224
# Epoch 11/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7866 - loss: 0.4407 - val_accuracy: 0.8055 - val_loss: 0.4220
# Epoch 12/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4198 - val_accuracy: 0.8055 - val_loss: 0.4218
# Epoch 13/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7889 - loss: 0.4244 - val_accuracy: 0.8013 - val_loss: 0.4217
# Epoch 14/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7949 - loss: 0.4324 - val_accuracy: 0.8034 - val_loss: 0.4204
# Epoch 15/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8055 - loss: 0.4188 - val_accuracy: 0.8048 - val_loss: 0.4200
# Epoch 16/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7956 - loss: 0.4233 - val_accuracy: 0.8034 - val_loss: 0.4198
# Epoch 17/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7928 - loss: 0.4327 - val_accuracy: 0.8048 - val_loss: 0.4185
# Epoch 18/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.4232 - val_accuracy: 0.8070 - val_loss: 0.4181
# Epoch 19/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7913 - loss: 0.4283 - val_accuracy: 0.8048 - val_loss: 0.4184
# Epoch 20/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7959 - loss: 0.4204 - val_accuracy: 0.8055 - val_loss: 0.4203
# Epoch 21/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8100 - loss: 0.4040 - val_accuracy: 0.8048 - val_loss: 0.4177
# Epoch 22/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7997 - loss: 0.4282 - val_accuracy: 0.8077 - val_loss: 0.4172
# Epoch 23/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7906 - loss: 0.4348 - val_accuracy: 0.8062 - val_loss: 0.4171
# Epoch 24/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.4268 - val_accuracy: 0.8048 - val_loss: 0.4172
# Epoch 25/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7966 - loss: 0.4245 - val_accuracy: 0.8055 - val_loss: 0.4168
# Epoch 26/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8009 - loss: 0.4138 - val_accuracy: 0.8070 - val_loss: 0.4167
# Epoch 27/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7973 - loss: 0.4214 - val_accuracy: 0.8055 - val_loss: 0.4164
# Epoch 28/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7985 - loss: 0.4171 - val_accuracy: 0.8027 - val_loss: 0.4186
# Epoch 29/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7987 - loss: 0.4191 - val_accuracy: 0.8048 - val_loss: 0.4178
# Epoch 30/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8036 - loss: 0.4223 - val_accuracy: 0.8034 - val_loss: 0.4163
# Epoch 31/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8036 - loss: 0.4142 - val_accuracy: 0.8041 - val_loss: 0.4183
# Epoch 32/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8052 - loss: 0.4143 - val_accuracy: 0.8020 - val_loss: 0.4162
# Epoch 33/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8012 - loss: 0.4184 - val_accuracy: 0.8027 - val_loss: 0.4183
# Epoch 34/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7998 - loss: 0.4166 - val_accuracy: 0.8034 - val_loss: 0.4167
# Epoch 35/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8023 - loss: 0.4211 - val_accuracy: 0.8084 - val_loss: 0.4155
# Epoch 36/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8042 - loss: 0.4135 - val_accuracy: 0.8048 - val_loss: 0.4164
# Epoch 37/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7954 - loss: 0.4180 - val_accuracy: 0.8048 - val_loss: 0.4170
# Epoch 38/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7935 - loss: 0.4352 - val_accuracy: 0.8077 - val_loss: 0.4157
# Epoch 39/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8070 - loss: 0.4100 - val_accuracy: 0.8027 - val_loss: 0.4165
# Epoch 40/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8041 - loss: 0.4125 - val_accuracy: 0.8105 - val_loss: 0.4154
# Epoch 41/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8090 - loss: 0.4110 - val_accuracy: 0.8013 - val_loss: 0.4182
# Epoch 42/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8049 - loss: 0.4183 - val_accuracy: 0.8055 - val_loss: 0.4150
# Epoch 43/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8053 - loss: 0.4221 - val_accuracy: 0.8055 - val_loss: 0.4166
# Epoch 44/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7922 - loss: 0.4255 - val_accuracy: 0.8055 - val_loss: 0.4163
# Epoch 45/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.4094 - val_accuracy: 0.8055 - val_loss: 0.4162
# Epoch 46/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.4255 - val_accuracy: 0.8098 - val_loss: 0.4154
# Epoch 47/50
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8119 - loss: 0.4100 - val_accuracy: 0.8091 - val_loss: 0.4153

# %% [markdown]
# ### 5) Métricas 📊

# %% [markdown]
# ***Ahora las métricas obtenidas son para best_model.***

# %% [markdown]
# **Matriz de Confusión**

# %%
y_pred = (best_model.predict(xtest) > 0.5)  # Convertir las probabilidades a 0 o 1
cm = confusion_matrix(ytest, y_pred)

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.title("Matriz de Confusión")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# **Reporte de Métricas**

# %%
report = classification_report(ytest, y_pred, target_names=['No', 'Yes'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.90      0.87      1032
#          Yes       0.67      0.54      0.60       377
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.72      0.73      1409
# weighted avg       0.80      0.81      0.80      1409

# %% [markdown]
# **Gráfica de Accuracy**

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy Entrenamiento')
plt.plot(history.history['val_accuracy'], label='Accuracy Validación')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Gráfica de Loss**

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Entrenamiento')
plt.plot(history.history['val_loss'], label='Loss Validación')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# **Curva ROC**

# %%
# Obtener las predicciones de probabilidades
y_pred_train = (best_model.predict(xtrain) > 0.5)  # Convertir las probabilidades a 0 o 1

# Calcular las métricas de la curva ROC para entrenamiento
fpr_train, tpr_train, _ = roc_curve(ytrain, y_pred_train)
roc_auc_train = auc(fpr_train, tpr_train)

# Calcular las métricas de la curva ROC para validación
fpr_val, tpr_val, _ = roc_curve(ytest, y_pred)
roc_auc_val = auc(fpr_val, tpr_val)

# Graficar ambas curvas ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_train, tpr_train, color='blue', lw=2, label=f'Train ROC (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_val, tpr_val, color='green', lw=2, label=f'Validation ROC (AUC = {roc_auc_val:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--', lw=2, label='Random guess')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC)', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.grid(alpha=0.3)
plt.show()
# Out:
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ### 6) Guardar el modelo 💾

# %% [markdown]
# ### 7) Hacer Predicciones en Producción 🤙

# %% [markdown]
# ### 8) Conclusiones
#
# - Aprender sobre los distintos objetos y métodos que nos ofrece Tensorflow + Keras.
#
# - Realizar el proceso completo de entrenamiento de un modelo con Tensorflow + Keras.
#
# - Aprender tips sobre implementación con el uso de la GPU.
#
# <br>
# <br>
# <br>

# %% [markdown]
# ---
#
# <br>
# <br>
#
#
# <img src="https://static.platzi.com/media/avatars/platziteam_8cfe6fc7-1246-4c9a-9f5d-d10d467443ee.png" width="100px">
#
# [Platzi](https://platzi.com/) 🚀
